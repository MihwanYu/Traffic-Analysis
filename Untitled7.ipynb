# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False)

# %%
road19 = pd.read_csv("C:\\data\\자전거도로(2019).csv",encoding= 'UTF8')
road19
# Out:
#       기간  자치구 자치구(2)  합계  합계.1 자전거전용도로 자전거전용도로.1  자전거보행자겸용도로  자전거보행자겸용도로.1  \
# 0   2019  도로변    종로구  24  23.7       -         -           6           5.9
# 1   2019  도로변     중구  12  15.4       -         -           2           2.4
# 2   2019  도로변    용산구  19  22.7       3         2          11          10.6
# 3   2019  도로변    성동구  21  19.9       2       0.6          10           9.2
# 4   2019  도로변    광진구  23  29.8       1       0.4          18          25.1
# 5   2019  도로변   동대문구  21  23.9       3       1.1          10           7.0
# 6   2019  도로변    중랑구   9   6.6       4       3.2           5           3.4
# 7   2019  도로변    성북구   8   7.7       1       0.3           5           4.7
# 8   2019  도로변    강북구   3   7.0       -         -           1           2.7
# 9   2019  도로변    도봉구   4  12.3       1       0.7           3          11.6
# 10  2019  도로변    노원구  25  28.3       1       0.9          17          19.9
# 11  2019  도로변    은평구  18  26.9       -         -          17          24.6
# 12  2019  도로변   서대문구  27  19.4       1       0.4           7           5.9
# 13  2019  도로변    마포구  33  34.6       5       4.2           4           5.4
# 14  2019  도로변    양천구  28  41.0      13      20.2          13          15.7
# 15  2019  도로변    강서구  43  41.7      19      17.7          24          24.0
# 16  2019  도로변    구로구  14  10.5       2         1           9           8.1
# 17  2019  도로변    금천구   7   8.2       2       3.8           5           4.4
# 18  2019  도로변   영등포구  47  37.0       6       3.2          12           5.0
# 19  2019  도로변    동작구  15  13.4       -         -          14          13.1
# 20  2019  도로변    관악구  15  19.5       1         3           5          12.2
# 21  2019  도로변    서초구  28  29.0       1       2.1          25          24.5
# 22  2019  도로변    강남구  26  52.6       3       3.1          21          48.0
# 23  2019  도로변    송파구  51  92.6      12        22          38          68.7
# 24  2019  도로변    강동구  33  42.1       5       8.5          27          33.0
#
#    자전거전용차로 자전거전용차로.1 자전거우선도로 자전거우선도로.1
# 0       10      10.9       8       6.9
# 1        1       0.7       9      12.3
# 2        -         -       5      10.1
# 3        2       4.8       7       5.3
# 4        1       0.5       3       3.8
# 5        1       1.4       7      14.4
# 6        -         -       -         -
# 7        1       2.4       1       0.3
# 8        2       4.3       -         -
# 9        -         -       -         -
# 10       7       7.5       -         -
# 11       1       2.3       -         -
# 12       2       1.9      17      11.2
# 13       7       5.2      17      19.8
# 14       -         -       2       5.1
# 15       -         -       -         -
# 16       1       0.4       2         1
# 17       -         -       -         -
# 18      14      12.6      15      16.2
# 19       -         -       1       0.3
# 20       -         -       9       4.3
# 21       2       2.4       -         -
# 22       2       1.5       -         -
# 23       1       1.9       -         -
# 24       1       0.6       -         -

# %%
road19 = road19[["자전거전용도로","자전거전용도로.1","자전거보행자겸용도로","자전거보행자겸용도로.1","자전거우선도로","자전거우선도로.1"]]
road19
# Out:
#    자전거전용도로 자전거전용도로.1  자전거보행자겸용도로  자전거보행자겸용도로.1 자전거우선도로 자전거우선도로.1
# 0        -         -           6           5.9       8       6.9
# 1        -         -           2           2.4       9      12.3
# 2        3         2          11          10.6       5      10.1
# 3        2       0.6          10           9.2       7       5.3
# 4        1       0.4          18          25.1       3       3.8
# 5        3       1.1          10           7.0       7      14.4
# 6        4       3.2           5           3.4       -         -
# 7        1       0.3           5           4.7       1       0.3
# 8        -         -           1           2.7       -         -
# 9        1       0.7           3          11.6       -         -
# 10       1       0.9          17          19.9       -         -
# 11       -         -          17          24.6       -         -
# 12       1       0.4           7           5.9      17      11.2
# 13       5       4.2           4           5.4      17      19.8
# 14      13      20.2          13          15.7       2       5.1
# 15      19      17.7          24          24.0       -         -
# 16       2         1           9           8.1       2         1
# 17       2       3.8           5           4.4       -         -
# 18       6       3.2          12           5.0      15      16.2
# 19       -         -          14          13.1       1       0.3
# 20       1         3           5          12.2       9       4.3
# 21       1       2.1          25          24.5       -         -
# 22       3       3.1          21          48.0       -         -
# 23      12        22          38          68.7       -         -
# 24       5       8.5          27          33.0       -         -

# %%
road19 = road19.rename({"자전거전용도로":"자전거전용도로 구간","자전거전용도로.1":"자전거전용도로 길이","자전거보행자겸용도로":"자전거보행자겸용도로 구간","자전거보행자겸용도로.1":"자전거보행자겸용도로 길이","자전거우선도로":"자전거우선도로 구간","자전거우선도로.1":"자전거우선도로 길이"},axis="columns")
road19
# Out:
#    자전거전용도로 구간 자전거전용도로 길이  자전거보행자겸용도로 구간  자전거보행자겸용도로 길이 자전거우선도로 구간 자전거우선도로 길이
# 0           -          -              6            5.9          8        6.9
# 1           -          -              2            2.4          9       12.3
# 2           3          2             11           10.6          5       10.1
# 3           2        0.6             10            9.2          7        5.3
# 4           1        0.4             18           25.1          3        3.8
# 5           3        1.1             10            7.0          7       14.4
# 6           4        3.2              5            3.4          -          -
# 7           1        0.3              5            4.7          1        0.3
# 8           -          -              1            2.7          -          -
# 9           1        0.7              3           11.6          -          -
# 10          1        0.9             17           19.9          -          -
# 11          -          -             17           24.6          -          -
# 12          1        0.4              7            5.9         17       11.2
# 13          5        4.2              4            5.4         17       19.8
# 14         13       20.2             13           15.7          2        5.1
# 15         19       17.7             24           24.0          -          -
# 16          2          1              9            8.1          2          1
# 17          2        3.8              5            4.4          -          -
# 18          6        3.2             12            5.0         15       16.2
# 19          -          -             14           13.1          1        0.3
# 20          1          3              5           12.2          9        4.3
# 21          1        2.1             25           24.5          -          -
# 22          3        3.1             21           48.0          -          -
# 23         12         22             38           68.7          -          -
# 24          5        8.5             27           33.0          -          -

# %%
type("자전거전용도로 구간")
# Out:
# str

# %%
road19["자전거전용도로 구간"]=pd.to_numeric(road19["자전거전용도로 구간"],errors="coerce")
road19["자전거전용도로 길이"]=pd.to_numeric(road19["자전거전용도로 길이"],errors="coerce")
road19["자전거보행자겸용도로 구간"]=pd.to_numeric(road19["자전거보행자겸용도로 구간"],errors="coerce")
road19["자전거보행자겸용도로 길이"]=pd.to_numeric(road19["자전거보행자겸용도로 길이"],errors="coerce")
road19["자전거우선도로 구간"]=pd.to_numeric(road19["자전거우선도로 구간"],errors="coerce")
road19["자전거우선도로 길이"]=pd.to_numeric(road19["자전거우선도로 길이"],errors="coerce")
road19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   자전거전용도로 구간     20 non-null     float64
#  1   자전거전용도로 길이     20 non-null     float64
#  2   자전거보행자겸용도로 구간  25 non-null     int64
#  3   자전거보행자겸용도로 길이  25 non-null     float64
#  4   자전거우선도로 구간     14 non-null     float64
#  5   자전거우선도로 길이     14 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 1.3 KB

# %%
road19 = road19.fillna(0)
road19.isnull().sum()
# Out:
# 자전거전용도로 구간       0
# 자전거전용도로 길이       0
# 자전거보행자겸용도로 구간    0
# 자전거보행자겸용도로 길이    0
# 자전거우선도로 구간       0
# 자전거우선도로 길이       0
# dtype: int64

# %%
road19_sum=road19.sum()
road19_sum=pd.DataFrame(road19_sum)
road19_sum
# Out:
#                    0
# 자전거전용도로 구간      86.0
# 자전거전용도로 길이      98.4
# 자전거보행자겸용도로 구간  309.0
# 자전거보행자겸용도로 길이  395.1
# 자전거우선도로 구간     103.0
# 자전거우선도로 길이     111.0

# %%
road19_1 =  [97,293,85]
road19_1_1 = ["자전거우선도로 구간","자전거보행자겸용도로 구간","자전거전용도로 구간"] 
plt.axis("equal")
plt.pie(road19_1,labels=road19_1_1,radius=1.0,autopct="%0.1f%%",shadow=True,explode=[0,0,0.2],startangle=45)
plt.legend(road19_1_1, loc="lower right")
plt.title("19년 도로별 구간 비율(단위:개)")
plt.show()

# %%
road19_2 =  [111,394.4,98.4]
road19_2_1 = ["자전거우선도로 길이","자전거보행자겸용도로 길이","자전거전용도로 길이"] 
plt.axis("equal")
plt.pie(road19_2,labels=road19_2_1,radius=1.0,autopct="%0.1f%%",shadow=True,explode=[0,0,0.2],startangle=45)
plt.legend(road19_2_1, loc="lower right")
plt.title("19년 도로별 길이 비율(단위:km)")
plt.show()

# %%
road20 = pd.read_csv("C:\\data\\자전거도로(2020).csv",encoding= 'UTF8')
road20
# Out:
#       기간  자치구 자치구(2)   합계  합계.1 자전거전용도로 자전거전용도로.1  자전거보행자겸용도로  자전거보행자겸용도로.1  \
# 0   2020  도로변    종로구   38  26.5       -         -           9           9.5
# 1   2020  도로변     중구   18  15.3       -         -           4           4.6
# 2   2020  도로변    용산구   26  33.0       5         2          11          10.6
# 3   2020  도로변    성동구   31  27.2       1       0.3          18          16.9
# 4   2020  도로변    광진구   50  46.8       1       0.2          43          41.7
# 5   2020  도로변   동대문구   30  37.8       4       1.4          12           7.6
# 6   2020  도로변    중랑구   16  10.0       7       3.5           9           6.5
# 7   2020  도로변    성북구   13   9.8       5       2.7           5           4.7
# 8   2020  도로변    강북구    8   8.7       -         -           3           3.2
# 9   2020  도로변    도봉구    8  12.9       2       1.4           6          11.5
# 10  2020  도로변    노원구   40  42.9       2       1.6          27          28.3
# 11  2020  도로변    은평구   30  39.8       -         -          28          37.2
# 12  2020  도로변   서대문구   47  31.1       -         -          17           7.6
# 13  2020  도로변    마포구   57  65.7       7         6           7          10.1
# 14  2020  도로변    양천구   59  55.5      25      22.1          30          23.3
# 15  2020  도로변    강서구   80  76.4      36      31.9          44          44.5
# 16  2020  도로변    구로구   38  26.5       4       1.8          32          23.8
# 17  2020  도로변    금천구   19   8.9       4       2.9          15           6.0
# 18  2020  도로변   영등포구   82  63.8       8       5.1          15           6.7
# 19  2020  도로변    동작구   17  13.9       -         -          15          13.1
# 20  2020  도로변    관악구   19  29.5       3       4.7           8          21.4
# 21  2020  도로변    서초구   44  37.4       2       2.2          38          30.7
# 22  2020  도로변    강남구   65  90.0       7      11.9          54          75.1
# 23  2020  도로변    송파구  186  97.1      44      19.4         140          75.9
# 24  2020  도로변    강동구   66  72.0      17      17.5          48          53.9
#
#    자전거전용차로 자전거전용차로.1 자전거우선도로 자전거우선도로.1
# 0       13       6.9      16      10.2
# 1        -         -      14      10.7
# 2        -         -      10      20.4
# 3        3         2       9         8
# 4        1       0.3       5       4.6
# 5        -         -      14      28.8
# 6        -         -       -         -
# 7        2       2.1       1       0.3
# 8        5       5.5       -         -
# 9        -         -       -         -
# 10      11        13       -         -
# 11       2       2.6       -         -
# 12       4       1.8      26      21.7
# 13      13        10      30      39.6
# 14       -         -       4      10.2
# 15       -         -       -         -
# 16       -         -       2         1
# 17       -         -       -         -
# 18      30      20.3      29      31.7
# 19       -         -       2       0.8
# 20       -         -       8       3.4
# 21       4       4.5       -         -
# 22       4         3       -         -
# 23       2       1.8       -         -
# 24       1       0.6       -         -

# %%
road20 = road20[["자전거전용도로","자전거전용도로.1","자전거보행자겸용도로","자전거보행자겸용도로.1","자전거우선도로","자전거우선도로.1"]]
road20
# Out:
#    자전거전용도로 자전거전용도로.1  자전거보행자겸용도로  자전거보행자겸용도로.1 자전거우선도로 자전거우선도로.1
# 0        -         -           9           9.5      16      10.2
# 1        -         -           4           4.6      14      10.7
# 2        5         2          11          10.6      10      20.4
# 3        1       0.3          18          16.9       9         8
# 4        1       0.2          43          41.7       5       4.6
# 5        4       1.4          12           7.6      14      28.8
# 6        7       3.5           9           6.5       -         -
# 7        5       2.7           5           4.7       1       0.3
# 8        -         -           3           3.2       -         -
# 9        2       1.4           6          11.5       -         -
# 10       2       1.6          27          28.3       -         -
# 11       -         -          28          37.2       -         -
# 12       -         -          17           7.6      26      21.7
# 13       7         6           7          10.1      30      39.6
# 14      25      22.1          30          23.3       4      10.2
# 15      36      31.9          44          44.5       -         -
# 16       4       1.8          32          23.8       2         1
# 17       4       2.9          15           6.0       -         -
# 18       8       5.1          15           6.7      29      31.7
# 19       -         -          15          13.1       2       0.8
# 20       3       4.7           8          21.4       8       3.4
# 21       2       2.2          38          30.7       -         -
# 22       7      11.9          54          75.1       -         -
# 23      44      19.4         140          75.9       -         -
# 24      17      17.5          48          53.9       -         -

# %%
road20 = road20.rename({"자전거전용도로":"자전거전용도로 구간","자전거전용도로.1":"자전거전용도로 길이","자전거보행자겸용도로":"자전거보행자겸용도로 구간","자전거보행자겸용도로.1":"자전거보행자겸용도로 길이","자전거우선도로":"자전거우선도로 구간","자전거우선도로.1":"자전거우선도로 길이"},axis="columns")
road20
# Out:
#    자전거전용도로 구간 자전거전용도로 길이  자전거보행자겸용도로 구간  자전거보행자겸용도로 길이 자전거우선도로 구간 자전거우선도로 길이
# 0           -          -              9            9.5         16       10.2
# 1           -          -              4            4.6         14       10.7
# 2           5          2             11           10.6         10       20.4
# 3           1        0.3             18           16.9          9          8
# 4           1        0.2             43           41.7          5        4.6
# 5           4        1.4             12            7.6         14       28.8
# 6           7        3.5              9            6.5          -          -
# 7           5        2.7              5            4.7          1        0.3
# 8           -          -              3            3.2          -          -
# 9           2        1.4              6           11.5          -          -
# 10          2        1.6             27           28.3          -          -
# 11          -          -             28           37.2          -          -
# 12          -          -             17            7.6         26       21.7
# 13          7          6              7           10.1         30       39.6
# 14         25       22.1             30           23.3          4       10.2
# 15         36       31.9             44           44.5          -          -
# 16          4        1.8             32           23.8          2          1
# 17          4        2.9             15            6.0          -          -
# 18          8        5.1             15            6.7         29       31.7
# 19          -          -             15           13.1          2        0.8
# 20          3        4.7              8           21.4          8        3.4
# 21          2        2.2             38           30.7          -          -
# 22          7       11.9             54           75.1          -          -
# 23         44       19.4            140           75.9          -          -
# 24         17       17.5             48           53.9          -          -

# %%
type("자전거전용도로 구간")
# Out:
# str

# %%
road20["자전거전용도로 구간"]=pd.to_numeric(road20["자전거전용도로 구간"],errors="coerce")
road20["자전거전용도로 길이"]=pd.to_numeric(road20["자전거전용도로 길이"],errors="coerce")
road20["자전거보행자겸용도로 구간"]=pd.to_numeric(road20["자전거보행자겸용도로 구간"],errors="coerce")
road20["자전거보행자겸용도로 길이"]=pd.to_numeric(road20["자전거보행자겸용도로 길이"],errors="coerce")
road20["자전거우선도로 구간"]=pd.to_numeric(road20["자전거우선도로 구간"],errors="coerce")
road20["자전거우선도로 길이"]=pd.to_numeric(road20["자전거우선도로 길이"],errors="coerce")
road20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   자전거전용도로 구간     19 non-null     float64
#  1   자전거전용도로 길이     19 non-null     float64
#  2   자전거보행자겸용도로 구간  25 non-null     int64
#  3   자전거보행자겸용도로 길이  25 non-null     float64
#  4   자전거우선도로 구간     14 non-null     float64
#  5   자전거우선도로 길이     14 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 1.3 KB

# %%
road20 = road20.fillna(0)
road20.isnull().sum()
# Out:
# 자전거전용도로 구간       0
# 자전거전용도로 길이       0
# 자전거보행자겸용도로 구간    0
# 자전거보행자겸용도로 길이    0
# 자전거우선도로 구간       0
# 자전거우선도로 길이       0
# dtype: int64

# %%
road20_sum=road20.sum()
road20_sum=pd.DataFrame(road20_sum)
road20_sum
# Out:
#                    0
# 자전거전용도로 구간     184.0
# 자전거전용도로 길이     138.6
# 자전거보행자겸용도로 구간  638.0
# 자전거보행자겸용도로 길이  574.4
# 자전거우선도로 구간     170.0
# 자전거우선도로 길이     191.4

# %%
road20_1 =  [170,638,184]
road20_1_1 = ["자전거우선도로 구간","자전거보행자겸용도로 구간","자전거전용도로 구간"] 
plt.axis("equal")
plt.pie(road20_1,labels=road20_1_1,radius=1.0,autopct="%0.1f%%",shadow=True,explode=[0,0,0.2],startangle=45)
plt.legend(road20_1_1, loc="lower right")
plt.title("20년 도로별 구간 비율(단위:개)")
plt.show()

# %%
road20_2 =  [191.4,574.4,138.6]
road20_2_1 = ["자전거우선도로 길이","자전거보행자겸용도로 길이","자전거전용도로 길이"] 
plt.axis("equal")
plt.pie(road20_2,labels=road20_2_1,radius=1.0,autopct="%0.1f%%",shadow=True,explode=[0,0,0.2],startangle=45)
plt.legend(road20_2_1, loc="lower right")
plt.title("20년 도로별 길이 비율(단위:km)")
plt.show()

# %%
road19_sum["20년"] = road20_sum[0]
road19_sum.rename(columns={0:"19년"},
                 inplace=True)
road19_sum
# Out:
#                  19년    20년
# 자전거전용도로 구간      86.0  184.0
# 자전거전용도로 길이      98.4  138.6
# 자전거보행자겸용도로 구간  309.0  638.0
# 자전거보행자겸용도로 길이  395.1  574.4
# 자전거우선도로 구간     103.0  170.0
# 자전거우선도로 길이     111.0  191.4

# %%
labels = ["자전거전용도로 구간","자전거우선도로 구간","자전거보행자겸용도로 구간"]

x = np.arange(len(labels))

count_1 = [85,97,293]
count_2 = [184,170,638]

width = 0.3

fig,axes = plt.subplots()

axes.barh(x-width/2,count_1,width,align="center",color="green",alpha=0.5)
axes.barh(x+width/2,count_2,width,align="center",color="red",alpha=0.5)

plt.xticks(fontsize=15)
plt.yticks(x)
axes.set_yticklabels(labels,fontsize=15)
plt.legend(["19년","20년"])
plt.xlabel("단위 : 개",fontsize=15)
plt.show()

# %%
labels = ["자전거전용도로 길이","자전거우선도로 길이","자전거보행자겸용도로 길이"]

x = np.arange(len(labels))

count_1 = [98.4,111,394.4]
count_2 = [138.5,191.5,574.3]

width = 0.3

fig,axes = plt.subplots()

axes.barh(x-width/2,count_1,width,align="center",color="green",alpha=0.5)
axes.barh(x+width/2,count_2,width,align="center",color="red",alpha=0.5)

plt.xticks(fontsize = 15)
plt.yticks(x)
axes.set_yticklabels(labels,fontsize=15)
plt.legend(["19년","20년"])
plt.xlabel("단위 : km",fontsize=15)
plt.show()

# %%
traffic19 = pd.read_csv("C:\\data\\자전거교통사고(2019).csv",encoding= 'euc_kr')
traffic19=traffic19[["지역","자전거 가해자사고"]]
traffic19
# Out:
#       지역  자전거 가해자사고
# 0    종로구         19
# 1     중구         23
# 2    용산구         22
# 3    성동구         63
# 4    광진구         61
# 5   동대문구        110
# 6    중랑구         99
# 7    성북구         37
# 8    강북구         57
# 9    도봉구         62
# 10   노원구        119
# 11   은평구         62
# 12  서대문구         48
# 13   마포구         52
# 14   양천구         70
# 15   강서구         72
# 16   구로구         71
# 17   금천구         40
# 18  영등포구        189
# 19   동작구         53
# 20   관악구         43
# 21   서초구         46
# 22   강남구         60
# 23   송파구        218
# 24   강동구         70

# %%
traffic20 = pd.read_csv("C:\\data\\자전거교통사고(2020).csv",encoding= 'euc_kr')
traffic20 = traffic20[["지역","자전거 가해자사고"]]
traffic20
# Out:
#       지역  자전거 가해자사고
# 0    종로구         20
# 1     중구         20
# 2    용산구         18
# 3    성동구         93
# 4    광진구         45
# 5   동대문구        114
# 6    중랑구        114
# 7    성북구         40
# 8    강북구         38
# 9    도봉구         57
# 10   노원구        112
# 11   은평구         43
# 12  서대문구         38
# 13   마포구         51
# 14   양천구         75
# 15   강서구         73
# 16   구로구         58
# 17   금천구         36
# 18  영등포구        210
# 19   동작구         67
# 20   관악구         44
# 21   서초구         60
# 22   강남구         99
# 23   송파구        198
# 24   강동구         79

# %%
traffic19["20년 자전거 가해자사고"]=traffic20["자전거 가해자사고"]
traffic19=traffic19.rename(columns={"자전거 가해자사고":"19년 자전거 가해자사고"})
traffic19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지역             25 non-null     object
#  1   19년 자전거 가해자사고  25 non-null     int64
#  2   20년 자전거 가해자사고  25 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 728.0+ bytes

# %%
traffic19["19년 자전거 가해자사고"]=pd.to_numeric(traffic19["19년 자전거 가해자사고"],errors="coerce")
traffic19["20년 자전거 가해자사고"]=pd.to_numeric(traffic19["20년 자전거 가해자사고"],errors="coerce")
traffic19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지역             25 non-null     object
#  1   19년 자전거 가해자사고  25 non-null     int64
#  2   20년 자전거 가해자사고  25 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 728.0+ bytes

# %%
traffic19["사고자 차이"] = traffic19["20년 자전거 가해자사고"] - traffic19["19년 자전거 가해자사고"]
traffic19
# Out:
#       지역  19년 자전거 가해자사고  20년 자전거 가해자사고  사고자 차이  구간차이
# 0    종로구             19             20       1     0
# 1     중구             23             20      -3     0
# 2    용산구             22             18      -4     2
# 3    성동구             63             93      30    -1
# 4    광진구             61             45     -16     0
# 5   동대문구            110            114       4     1
# 6    중랑구             99            114      15     3
# 7    성북구             37             40       3     4
# 8    강북구             57             38     -19     0
# 9    도봉구             62             57      -5     1
# 10   노원구            119            112      -7     1
# 11   은평구             62             43     -19     0
# 12  서대문구             48             38     -10    -1
# 13   마포구             52             51      -1     2
# 14   양천구             70             75       5    12
# 15   강서구             72             73       1    17
# 16   구로구             71             58     -13     2
# 17   금천구             40             36      -4     2
# 18  영등포구            189            210      21     2
# 19   동작구             53             67      14     0
# 20   관악구             43             44       1     2
# 21   서초구             46             60      14     1
# 22   강남구             60             99      39     4
# 23   송파구            218            198     -20    32
# 24   강동구             70             79       9    12

# %%
bicycle19 = pd.read_csv("C:\\data\\자전거도로(2019).csv",encoding= 'UTF8')
bicycle19 = bicycle19[["자치구(2)","자전거전용도로"]]
bicycle19=bicycle19.replace({"-":0})
bicycle19
# Out:
#    자치구(2) 자전거전용도로
# 0     종로구       0
# 1      중구       0
# 2     용산구       3
# 3     성동구       2
# 4     광진구       1
# 5    동대문구       3
# 6     중랑구       4
# 7     성북구       1
# 8     강북구       0
# 9     도봉구       1
# 10    노원구       1
# 11    은평구       0
# 12   서대문구       1
# 13    마포구       5
# 14    양천구      13
# 15    강서구      19
# 16    구로구       2
# 17    금천구       2
# 18   영등포구       6
# 19    동작구       0
# 20    관악구       1
# 21    서초구       1
# 22    강남구       3
# 23    송파구      12
# 24    강동구       5

# %%
bicycle20 = pd.read_csv("C:\\data\\자전거도로(2020).csv",encoding= 'UTF8')
bicycle20 = bicycle20[["자치구(2)","자전거전용도로"]]
bicycle20=bicycle20.replace({"-":0})
bicycle20
# Out:
#    자치구(2) 자전거전용도로
# 0     종로구       0
# 1      중구       0
# 2     용산구       5
# 3     성동구       1
# 4     광진구       1
# 5    동대문구       4
# 6     중랑구       7
# 7     성북구       5
# 8     강북구       0
# 9     도봉구       2
# 10    노원구       2
# 11    은평구       0
# 12   서대문구       0
# 13    마포구       7
# 14    양천구      25
# 15    강서구      36
# 16    구로구       4
# 17    금천구       4
# 18   영등포구       8
# 19    동작구       0
# 20    관악구       3
# 21    서초구       2
# 22    강남구       7
# 23    송파구      44
# 24    강동구      17

# %%
bicycle19["20년 자전거 전용도로구간"]=bicycle20["자전거전용도로"]
bicycle19=bicycle19.rename(columns={"자전거전용도로":"19년 자전거 전용도로구간"})
bicycle19
# Out:
#    자치구(2) 19년 자전거 전용도로구간 20년 자전거 전용도로구간
# 0     종로구              0              0
# 1      중구              0              0
# 2     용산구              3              5
# 3     성동구              2              1
# 4     광진구              1              1
# 5    동대문구              3              4
# 6     중랑구              4              7
# 7     성북구              1              5
# 8     강북구              0              0
# 9     도봉구              1              2
# 10    노원구              1              2
# 11    은평구              0              0
# 12   서대문구              1              0
# 13    마포구              5              7
# 14    양천구             13             25
# 15    강서구             19             36
# 16    구로구              2              4
# 17    금천구              2              4
# 18   영등포구              6              8
# 19    동작구              0              0
# 20    관악구              1              3
# 21    서초구              1              2
# 22    강남구              3              7
# 23    송파구             12             44
# 24    강동구              5             17

# %%
bicycle19["19년 자전거 전용도로구간"]=pd.to_numeric(bicycle19["19년 자전거 전용도로구간"],errors="coerce")
bicycle19["20년 자전거 전용도로구간"]=pd.to_numeric(bicycle19["20년 자전거 전용도로구간"],errors="coerce")
bicycle19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   자치구(2)          25 non-null     object
#  1   19년 자전거 전용도로구간  25 non-null     int64
#  2   20년 자전거 전용도로구간  25 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 728.0+ bytes

# %%
bicycle19["구간차이"] = bicycle19["20년 자전거 전용도로구간"] - bicycle19["19년 자전거 전용도로구간"]
bicycle19
# Out:
#    자치구(2)  19년 자전거 전용도로구간  20년 자전거 전용도로구간  구간차이
# 0     종로구               0               0     0
# 1      중구               0               0     0
# 2     용산구               3               5     2
# 3     성동구               2               1    -1
# 4     광진구               1               1     0
# 5    동대문구               3               4     1
# 6     중랑구               4               7     3
# 7     성북구               1               5     4
# 8     강북구               0               0     0
# 9     도봉구               1               2     1
# 10    노원구               1               2     1
# 11    은평구               0               0     0
# 12   서대문구               1               0    -1
# 13    마포구               5               7     2
# 14    양천구              13              25    12
# 15    강서구              19              36    17
# 16    구로구               2               4     2
# 17    금천구               2               4     2
# 18   영등포구               6               8     2
# 19    동작구               0               0     0
# 20    관악구               1               3     2
# 21    서초구               1               2     1
# 22    강남구               3               7     4
# 23    송파구              12              44    32
# 24    강동구               5              17    12

# %%
labels = ["19년 자전거전용도로구간","20년 자전거전용도로구간"]

x = np.arange(len(labels))

count_1 = [12,44]
count_2 = [218,198]

width = 0.3

fig,axes = plt.subplots()
axes.barh(x-width/2,count_1,width,align="center",color="green",alpha=0.5)
axes.barh(x+width/2,count_2,width,align="center",color="red",alpha=0.5)

plt.xticks(fontsize = 15)
plt.yticks(x)
axes.set_yticklabels(labels,fontsize=15)
plt.title("송파구 자전거전용도로 증가에 따른 교통사고 수",fontsize=20)
plt.legend(["자전거전용도로 수","교통사고 수"])
plt.show()

# %%
labels = ["19년 자전거전용도로구간","20년 자전거전용도로구간"]

x = np.arange(len(labels))

count_1 = [2,1]
count_2 = [63,93]

width = 0.3

fig,axes = plt.subplots()
axes.barh(x-width/2,count_1,width,align="center",color="green",alpha=0.5)
axes.barh(x+width/2,count_2,width,align="center",color="red",alpha=0.5)

plt.xticks(fontsize = 15)
plt.yticks(x)
axes.set_yticklabels(labels,fontsize=15)
plt.title("성동구 자전거전용도로 감소에 따른 교통사고 수",fontsize=20)
plt.legend(["도로구간 수","교통사고 수"])
plt.show()

# %%
traffic19["구간차이"] =  bicycle19["구간차이"]
traffic19
raw = traffic19[["사고자 차이","구간차이"]]
raw.corr()
# Out:
#           사고자 차이      구간차이
# 사고자 차이  1.000000 -0.151658
# 구간차이   -0.151658  1.000000
